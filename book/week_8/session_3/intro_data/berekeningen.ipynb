# %%
import sympy as sym

# %%
kappa_AC = sym.nsimplify(1e-5) * 50 / 10 * 4
display(kappa_AC, kappa_AC.evalf())

eps_AC = sym.nsimplify(1e-5) * 50

display(eps_AC, eps_AC.evalf())
# Out:
# 1/5000
# 0.000200000000000000
# 1/2000
# 0.000500000000000000

# %%
EI = sym.nsimplify(20e3)
EA = sym.nsimplify(4e3)
q = sym.symbols('q')
q_sol = 5
N_CD = sym.symbols('N_CD')

deltaT_AC = 50
deltaT_CD = 50
h = sym.nsimplify(0.4)
alpha = sym.nsimplify(1e-5)

# %%
T, N = sym.symbols('T N')

T_sol = EI * kappa_AC
N_sol = EA * eps_AC
display(T_sol, T_sol.evalf())
display(N_sol, N_sol.evalf())
# Out:
# 4
# 4.00000000000000
# 2
# 2.00000000000000

# %%
M_B = q * 6 * 6 / 2 + N_CD * 6 + T
M_BC = M_B / 2 + q * 6**2 / 6
M_BC_hulp = M_BC + q * 6**2 / 6
display(M_B, M_B.evalf())
phi_A = M_B * 4 / 6 / EI + T * 4 / 3 / EI
phi_B = M_B * 4 / 3 / EI + T * 4 / 6 / EI
w_AB = M_B * 4 **2 / EI / 16 + T * 4 **2 / 16 / EI
w_CD = T * 6 **2 / 16 / EI + T * 6 **2 / 16 / EI
display(phi_B, phi_B.evalf())
w_C_BC = phi_B * 6 + T * 6 **2 / 2 / EI + N_CD * 6**3 / 3 / EI
display(w_C_BC, w_C_BC.evalf())
w_C_CD = N_CD * 4 / EA + N * 4 / EA
display(w_C_CD, w_C_CD.evalf())

eq1 = sym.Eq(w_C_BC, w_C_CD)
sol = sym.solve(eq1.subs(T,T_sol).subs(N,N_sol), N_CD)[0]
display(sol)
display(sol.subs(q,q_sol))
# Out:
# 6*N_CD + T + 18*q
# 6.0*N_CD + T + 18.0*q
# N_CD/2500 + T/10000 + 3*q/2500
# 0.0004*N_CD + 0.0001*T + 0.0012*q
# 3*N_CD/500 + 3*T/2000 + 9*q/1250
# 0.006*N_CD + 0.0015*T + 0.0072*q
# N/1000 + N_CD/1000
# 0.001*N + 0.001*N_CD
# -36*q/25 - 4/5
# -8

# %%
display(M_B.subs(N_CD,sol).subs(T,0).subs(N,0).subs(q,q_sol))
display(M_BC_hulp.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol))
display(M_BC.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol))
display(phi_B.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(phi_A.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(w_AB.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(w_CD.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(w_C_BC.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(w_C_CD.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
# Out:
# 42
# 83
# 53
# 0.00320000000000000
# 0.00180000000000000
# 0.00250000000000000
# 0.000900000000000000
# -0.00600000000000000
# -0.00600000000000000

# %%
display(M_B.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
display(M_BC_hulp.subs(N_CD,sol).subs(T,T_sol).subs(N,N_sol).subs(q,q_sol).evalf())
# Out:
# 46.0000000000000
# 83.0000000000000
